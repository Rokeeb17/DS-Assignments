# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
earthQuakes = pd.read_csv('all_month.csv')
pd.options.display.max_rows=9999
print(earthQuakes.to_string())
# Out:
#                           time   latitude   longitude       depth       mag     magType    nst         gap       dmin       rms net             id                   updated                                                   place          type  horizontalError  depthError  magError  magNst     status locationSource magSource
# 0     2023-09-24T02:32:24.208Z  60.240700 -151.038500   54.600000  1.100000          ml    NaN         NaN        NaN  0.520000  ak   ak023c9lvfq9  2023-09-24T02:34:28.879Z                                 Kenai Peninsula, Alaska    earthquake              NaN    1.600000       NaN     NaN  automatic             ak        ak
# 1     2023-09-24T02:32:04.780Z  38.822334 -122.850998   -0.630000  0.650000          md   10.0  123.000000   0.021710  0.210000  nc     nc73941066  2023-09-24T02:33:39.590Z                            10 km WNW of The Geysers, CA    earthquake         0.510000    2.400000  0.340000     8.0  automatic             nc        nc
# ...

# %%
earthQuakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9662 entries, 0 to 9661
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             9662 non-null   object
#  1   latitude         9662 non-null   float64
#  2   longitude        9662 non-null   float64
#  3   depth            9662 non-null   float64
#  4   mag              9661 non-null   float64
#  5   magType          9661 non-null   object
#  6   nst              7316 non-null   float64
#  7   gap              7316 non-null   float64
#  8   dmin             5868 non-null   float64
#  9   rms              9662 non-null   float64
#  10  net              9662 non-null   object
#  11  id               9662 non-null   object
#  12  updated          9662 non-null   object
#  13  place            9662 non-null   object
#  14  type             9662 non-null   object
#  15  horizontalError  6691 non-null   float64
# ...

# %%
 statsOfData = earthQuakes.describe()
 statsOfData
# Out:
#           latitude    longitude        depth          mag          nst  \
# count  9662.000000  9662.000000  9662.000000  9661.000000  7316.000000
# mean     40.912697  -116.671667    23.355603     1.565404    22.765856
# std      18.974728    65.423597    52.890429     1.202643    22.257144
# min     -65.899300  -179.994000    -3.430000    -1.020000     0.000000
# 25%      33.991375  -152.311550     2.850000     0.770000    10.000000
# 50%      38.836499  -122.788833     8.180000     1.340000    16.000000
# 75%      57.997700  -116.590667    17.007500     2.000000    28.000000
# max      79.568100   179.977500   649.778000     7.100000   393.000000
#
#                gap         dmin          rms  horizontalError   depthError  \
# count  7316.000000  5868.000000  9662.000000      6691.000000  9661.000000
# mean    117.215181     0.595249     0.288808         1.673778     2.099876
# std      66.359577     2.084116     0.266167         3.799421     4.939657
# ...

# %%
correlations = earthQuakes.corr(numeric_only=True)
correlations
# Out:
#                  latitude  longitude     depth       mag       nst       gap  \
# latitude         1.000000  -0.441747 -0.201168 -0.507520 -0.325689  0.133437
# longitude       -0.441747   1.000000  0.180092  0.521900  0.296172 -0.016658
# depth           -0.201168   0.180092  1.000000  0.397018  0.236176 -0.035670
# mag             -0.507520   0.521900  0.397018  1.000000  0.552070 -0.035497
# nst             -0.325689   0.296172  0.236176  0.552070  1.000000 -0.343046
# gap              0.133437  -0.016658 -0.035670 -0.035497 -0.343046  1.000000
# dmin            -0.534719   0.399187  0.244394  0.522390  0.244206  0.012922
# rms              0.074607   0.195342  0.336561  0.547678  0.420598  0.024508
# horizontalError -0.418451   0.459751  0.468065  0.578255  0.242803  0.138834
# depthError      -0.164113   0.167690  0.122771  0.180122 -0.014978  0.161463
# magError        -0.041930  -0.154416 -0.025869 -0.046842  0.007203  0.049996
# ...
